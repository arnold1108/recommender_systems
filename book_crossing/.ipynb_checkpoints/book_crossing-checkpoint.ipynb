# %% [markdown]
# # Books Recommendations with Collaborative Filtering and Cosine Distance

# %% [markdown]
# ## The Data

# %% [markdown]
# In this project, [Book-Crossing](http://www2.informatik.uni-freiburg.de/~cziegler/BX/) data was used to build an item based collaborative filtering books recommender system.

# %% [markdown]
# ### Metadata
# The data contains three tables; the users info, ratings and books info. It contains 1.1 million ratings of 270,000 books by 90,000 users.
# * The ratings data set provides a list of ratings that users have given to books. It includes 1,149,780 records and 3 fields: userID, ISBN, and bookRating. The ratings are on a scale from 1 to 10.
# * The books data set provides book details. It includes 271,360 records and 8 fields: ISBN, book title, book author, publisher and so on.
# * The users data provides the user demographic information. It includes 278,858 records and 3 fields: user id, location and age.

# %% [markdown]
# ### Importing the necessary libraries

# %%
from dask.distributed import Client
import dask.array as da
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Intergating dask dashboard
client = Client('tcp://dc-arnol-data-science-322b6c2166d84385a76c114f6c30216c.main-namespace:8786')
client
x = da.random.random((10000, 10000), chunks='16 MiB')
x
# Out:
# dask.array<random_sample, shape=(10000, 10000), dtype=float64, chunksize=(1250, 1250), chunktype=numpy.ndarray>

# %% [markdown]
# ### Loading the dataset

# %%
books_df = pd.read_csv('./datasets/BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")
ratings_df = pd.read_csv('./datasets/BX-Book-Ratings.csv', sep=';', error_bad_lines=False, encoding="latin-1")
users_df = pd.read_csv('./datasets/BX-Users.csv', sep=';', error_bad_lines=False, encoding="latin-1")
# Out:
# /tmp/ipykernel_540/2872301834.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   books_df = pd.read_csv('./datasets/BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# ...

# %%
print(books_df.shape)
books_df.head()
# Out:
# (271360, 8)
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
print(ratings_df.shape)
ratings_df.head()
# Out:
# (1149780, 3)
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(users_df.shape)
users_df.head()
# Out:
# (278858, 3)
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# #### Checking for and dealing with missing values

# %%
sns.heatmap(ratings_df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(books_df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(users_df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# What percentage of the Age variable is missing?

# %%
users_df['Age'].isnull().sum()/len(users_df) * 100
# Out:
# 39.71985741847105

# %% [markdown]
# Close to 40% of the values in that variable are missing. We will deal with them later on
